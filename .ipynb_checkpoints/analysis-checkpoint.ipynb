# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # drift relative to system time

# %% [markdown]
# ## experiment 4

# %%
rate4 = [2, 3, 5]

df41 = pd.read_csv("data/4_machine1.csv")
df42 = pd.read_csv("data/4_machine2.csv")
df43 = pd.read_csv("data/4_machine3.csv")

df41.iloc[100:200]
# Out:
#      Unnamed: 0 event_type   system_time  old_clock_time  new_clock_time  \
# 100         100    receive   52063464692             247             248
# 101         101   sendboth   52568056990             248             249
# 102         102   internal   53070585807             249             250
# 103         103    receive   53575617833             250             252
# 104         104   internal   54080672370             252             253
# ..          ...        ...           ...             ...             ...
# 195         195   internal  100033469225             481             482
# 196         196    receive  100537957886             482             487
# 197         197   sendboth  101043554901             487             488
# 198         198   internal  101548602896             488             489
# 199         199   internal  102053981324             489             490
#
#      message_queue_length
# 100                     0
# 101                     0
# ...

# %%
df4 = df41.copy(deep=True)
df4['machine'] = 1

df42['machine'] = 2

# %%
plt.scatter(df41.iloc[:50].system_time, df41.iloc[:50].new_clock_time, c='g', s=2, label="Rate = 2")
plt.scatter(df42.iloc[:50].system_time, df42.iloc[:50].new_clock_time, c='b', s=2, label="Rate = 3")
plt.scatter(df43.iloc[:50].system_time, df43.iloc[:50].new_clock_time, c='purple', s=2, label="Rate = 5")

plt.title("Experiment 4")
plt.xlabel("System Time (Nanoseconds)")
plt.ylabel("Logical Clock Value")

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()

# %% [markdown]
# ## experiment 5

# %%
rate5 = [4, 5, 4]

df51 = pd.read_csv("data/5_machine1.csv")
df52 = pd.read_csv("data/5_machine2.csv")
df53 = pd.read_csv("data/5_machine3.csv")

df53
# Out:
#       Unnamed: 0 event_type   system_time  old_clock_time  new_clock_time  \
# 0              0   internal    1151439182               0               1
# 1              1    receive    1407268062               1               2
# 2              2   internal    1663129645               2               3
# 3              3    receive    1918350320               3               5
# 4              4   internal    2173922397               5               6
# ...          ...        ...           ...             ...             ...
# 1035        1035      send2  264722179142            1344            1345
# 1036        1036   internal  264976760884            1345            1346
# 1037        1037    receive  265230245072            1346            1347
# 1038        1038   sendboth  265483344917            1347            1348
# 1039        1039   internal  265740052024            1348            1349
#
#       message_queue_length
# 0                        0
# ...

# %%
plt.scatter(df51.iloc[:50].system_time, df51.iloc[:50].new_clock_time, c='g', s=2, label="Rate = 4")
plt.scatter(df52.iloc[:50].system_time, df52.iloc[:50].new_clock_time, c='b', s=2, label="Rate = 5")
plt.scatter(df53.iloc[:50].system_time, df53.iloc[:50].new_clock_time, c='purple', s=2, label="Rate = 4")

plt.title("Experiment 5")
plt.xlabel("System Time (Nanoseconds)")
plt.ylabel("Logical Clock Value")

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()

# %% [markdown]
# ## experiment 6

# %%
rate6 = [1, 6, 3]

df61 = pd.read_csv("data/6_machine1.csv")
df62 = pd.read_csv("data/6_machine2.csv")
df63 = pd.read_csv("data/6_machine3.csv")

# %%
plt.scatter(df61.iloc[:50].system_time, df61.iloc[:50].new_clock_time, c='g', s=2, label="Rate = 1")
plt.scatter(df62.iloc[:50].system_time, df62.iloc[:50].new_clock_time, c='b', s=2, label="Rate = 6")
plt.scatter(df63.iloc[:50].system_time, df63.iloc[:50].new_clock_time, c='purple', s=2, label="Rate = 3")

plt.title("Experiment 6")
plt.xlabel("System Time (Nanoseconds)")
plt.ylabel("Logical Clock Value")

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()

# %% [markdown]
# ## experiment 7

# %%
rate7 = [2, 4, 1]

df71 = pd.read_csv("data/7_machine1.csv")
df72 = pd.read_csv("data/7_machine2.csv")
df73 = pd.read_csv("data/7_machine3.csv")

# %%
plt.scatter(df71.iloc[:50].system_time, df71.iloc[:50].new_clock_time, c='g', s=2, label="Rate = 2")
plt.scatter(df72.iloc[:50].system_time, df72.iloc[:50].new_clock_time, c='b', s=2, label="Rate = 6")
plt.scatter(df73.iloc[:50].system_time, df73.iloc[:50].new_clock_time, c='purple', s=2, label="Rate = 3")

plt.title("Experiment 7")
plt.xlabel("System Time (Nanoseconds)")
plt.ylabel("Logical Clock Value")

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()

# %% [markdown]
# ## experiment 8

# %%
rate8 = [6, 2, 5]

df81 = pd.read_csv("data/8_machine1.csv")
df82 = pd.read_csv("data/8_machine2.csv")
df83 = pd.read_csv("data/8_machine3.csv")

# %%
plt.scatter(df81.iloc[:50].system_time, df81.iloc[:50].new_clock_time, c='g', s=2, label="Rate = 6")
plt.scatter(df82.iloc[:50].system_time, df82.iloc[:50].new_clock_time, c='b', s=2, label="Rate = 2")
plt.scatter(df83.iloc[:50].system_time, df83.iloc[:50].new_clock_time, c='purple', s=2, label="Rate = 5")

plt.title("Experiment 8")
plt.xlabel("System Time (Nanoseconds)")
plt.ylabel("Logical Clock Value")

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()

# %% [markdown]
# ## experiment 9

# %%
rate9 = [6, 1, 3]

df91 = pd.read_csv("data/9_machine1.csv")
df92 = pd.read_csv("data/9_machine2.csv")
df93 = pd.read_csv("data/9_machine3.csv")

# %%
plt.scatter(df91.iloc[:50].system_time, df91.iloc[:50].new_clock_time, c='g', s=2, label="Rate = 6")
plt.scatter(df92.iloc[:50].system_time, df92.iloc[:50].new_clock_time, c='b', s=2, label="Rate = 1")
plt.scatter(df93.iloc[:50].system_time, df93.iloc[:50].new_clock_time, c='purple', s=2, label="Rate = 3")

plt.title("Experiment 9")
plt.xlabel("System Time (Nanoseconds)")
plt.ylabel("Logical Clock Value")

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()

# %% [markdown]
# # overwritten by incoming messages

# %% [markdown]
# # frequency of send vs receive

# %%
def label_function(val):
    return f'{val / 100 * len(df):.0f}\n{val:.0f}%'

fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=(10, 5))


df71['event_type'] = df71['event_type'].replace(['send1', 'send2', 'sendboth'], 'send')

df71.groupby('event_type').size().plot(kind='pie', textprops={'fontsize': 10},
                                  colors=['tomato', 'gold', 'skyblue'])
# Out:
# <AxesSubplot: >
